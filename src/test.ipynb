# %%
import pyproj

P = pyproj.Proj(proj='utm', zone=32, ellps='WGS84', preserve_units=True)
G = pyproj.Geod(ellps='WGS84')

def LonLat_To_XY(Lon, Lat):
    return P(Lon, Lat)


x = LonLat_To_XY(12.4924, 41.8902)  # Longitude and Latitude of the Colosseum in Rome
print(f"UTM Coordinates: {x}")
# Out:
# UTM Coordinates: (789748.6650596443, 4643485.524607192)

# %%
def distance(Lat1, Lon1, Lat2, Lon2):
    return G.inv(Lon1, Lat1, Lon2, Lat2)[2]

# %%
d = distance(41.8902, 12.4924, 48.8584, 2.2945)  # Colosseum to Eiffel Tower
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 d = distance(41.8902, 12.4924, 48.8584, 2.2945)  # Colosseum to Eiffel Tower
#
# Cell In[1], line 2, in distance(Lat1, Lon1, Lat2, Lon2)
#       1 def distance(Lat1, Lon1, Lat2, Lon2):
# ----> 2     return G.inv(Lon1, Lat1, Lon2, Lat2)[2]
#
# NameError: name 'G' is not defined

# %%
d = distance(41.8902, 12.4924, 48.8584, 2.2945)  # Colosseum to Eiffel Tower
